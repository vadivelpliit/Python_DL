# %% [markdown]
# Author: Vadivel, PL (PV48452)

# %%
import pandas as pd
# Read from csv
Train = pd.read_csv('/var/app/anaconda/projects/pv48452/fintech_modeling_gateway2/pv48452/titanic.csv') #back slash in path - within single quotes

# %%
######################################  Conditional Row selection ###########################################

# %%
Train['survived']>0 # Returns a boolean dataframe of true or false
# Out:
# 0        True
# 1        True
# 2       False
# 3       False
# 4       False
# 5        True
# 6        True
# 7       False
# 8        True
# 9       False
# 10      False
# 11       True
# 12       True
# 13       True
# 14       True
# 15      False
# 16      False
# 17       True
# 18       True
# 19      False
# 20       True
# 21       True
# 22       True
# 23       True
# 24       True
# 25      False
# 26       True
# 27       True
# 28       True
# 29       True
#         ...
# 1279    False
# 1280    False
# 1281    False
# 1282    False
# 1283    False
# 1284    False
# 1285    False
# 1286     True
# 1287    False
# 1288    False
# 1289    False
# 1290     True
# 1291    False
# 1292    False
# 1293    False
# 1294    False
# 1295    False
# 1296    False
# 1297    False
# 1298    False
# 1299    False
# 1300     True
# 1301    False
# 1302    False
# 1303    False
# 1304    False
# 1305    False
# 1306    False
# 1307    False
# 1308    False
# ...

# %%
Train[Train['survived']>0] # This will retain only rows where inside condition returned true. inside condition will return boolean series. for whichever row the series value is false, that row will be dropped
# Out:
#       pclass  survived                                               name  \
# 0          1         1                      Allen  Miss. Elisabeth Walton
# 1          1         1                     Allison  Master. Hudson Trevor
# 5          1         1                                Anderson  Mr. Harry
# 6          1         1                  Andrews  Miss. Kornelia Theodosia
# 8          1         1      Appleton  Mrs. Edward Dale (Charlotte Lamson)
# 11         1         1  Astor  Mrs. John Jacob (Madeleine Talmadge Force)
# 12         1         1                      Aubart  Mme. Leontine Pauline
# 13         1         1                         Barber  Miss. Ellen Nellie
# 14         1         1               Barkworth  Mr. Algernon Henry Wilson
# 17         1         1    Baxter  Mrs. James (Helene DeLaudeniere Chaput)
# 18         1         1                              Bazzani  Miss. Albina
# 20         1         1                      Beckwith  Mr. Richard Leonard
# ...

# %%
Train[(Train['survived']>0) & (Train['pclass']==1)] #'and' will work only for individual value, will not work for list. so use '&'. Similarly use '|' instead of 'or' for series comparison
# Out:
#      pclass  survived                                               name  \
# 0         1         1                      Allen  Miss. Elisabeth Walton
# 1         1         1                     Allison  Master. Hudson Trevor
# 5         1         1                                Anderson  Mr. Harry
# 6         1         1                  Andrews  Miss. Kornelia Theodosia
# 8         1         1      Appleton  Mrs. Edward Dale (Charlotte Lamson)
# 11        1         1  Astor  Mrs. John Jacob (Madeleine Talmadge Force)
# 12        1         1                      Aubart  Mme. Leontine Pauline
# 13        1         1                         Barber  Miss. Ellen Nellie
# 14        1         1               Barkworth  Mr. Algernon Henry Wilson
# 17        1         1    Baxter  Mrs. James (Helene DeLaudeniere Chaput)
# 18        1         1                              Bazzani  Miss. Albina
# 20        1         1                      Beckwith  Mr. Richard Leonard
# ...

# %%
Train[(Train['survived']>0) & (Train['pclass']==1)][['fare','name']] #conditional row selection and selecting specific columns
# Out:
#          fare                                               name
# 0    211.3375                      Allen  Miss. Elisabeth Walton
# 1    151.5500                     Allison  Master. Hudson Trevor
# 5     26.5500                                Anderson  Mr. Harry
# 6     77.9583                  Andrews  Miss. Kornelia Theodosia
# 8     51.4792      Appleton  Mrs. Edward Dale (Charlotte Lamson)
# 11   227.5250  Astor  Mrs. John Jacob (Madeleine Talmadge Force)
# 12    69.3000                      Aubart  Mme. Leontine Pauline
# 13    78.8500                         Barber  Miss. Ellen Nellie
# 14    30.0000               Barkworth  Mr. Algernon Henry Wilson
# 17   247.5208    Baxter  Mrs. James (Helene DeLaudeniere Chaput)
# 18    76.2917                              Bazzani  Miss. Albina
# 20    52.5542                      Beckwith  Mr. Richard Leonard
# 21    52.5542   Beckwith  Mrs. Richard Leonard (Sallie Monypeny)
# ...

# %%
Train1 = Train[Train['embarked'].isin(['C','S'])]
Train1
# Out:
#       pclass  survived                                               name  \
# 0          1         1                      Allen  Miss. Elisabeth Walton
# 1          1         1                     Allison  Master. Hudson Trevor
# 2          1         0                       Allison  Miss. Helen Loraine
# 3          1         0               Allison  Mr. Hudson Joshua Creighton
# 4          1         0    Allison  Mrs. Hudson J C (Bessie Waldo Daniels)
# 5          1         1                                Anderson  Mr. Harry
# 6          1         1                  Andrews  Miss. Kornelia Theodosia
# 7          1         0                             Andrews  Mr. Thomas Jr
# 8          1         1      Appleton  Mrs. Edward Dale (Charlotte Lamson)
# 9          1         0                            Artagaveytia  Mr. Ramon
# 10         1         0                             Astor  Col. John Jacob
# 11         1         1  Astor  Mrs. John Jacob (Madeleine Talmadge Force)
# ...

# %%
Train[Train['survived']>0]['sex'].value_counts()
# Out:
# female    339
# male      161
# Name: sex, dtype: int64

# %%
len(Train[Train['survived']>0]) #number of people who survived
# Out:
# 500

# %%
Train[Train['survived']==1]['age'].mean() #Average age of people who survived
# Out:
# 28.918228103044495

# %%
Train[(~Train.age.isnull()) & (Train.survived==0)][0:5][['age','sex','survived']] #showing first five rows of members whose age is known and not survived - only two columns
# Out:
#     age     sex  survived
# 2   2.0  female         0
# 3  30.0    male         0
# 4  25.0  female         0
# 7  39.0    male         0
# 9  71.0    male         0

# %%
Train[(Train.survived==1) & (Train.sex.str.startswith('m'))]['age'].mean() # Average age of male people who survived
# Out:
# 26.977777777777778

# %%
Train[Train['embarked'].notnull()] #Select rows where Embarked is not null/NaN
# Out:
#       pclass  survived                                               name  \
# 0          1         1                      Allen  Miss. Elisabeth Walton
# 1          1         1                     Allison  Master. Hudson Trevor
# 2          1         0                       Allison  Miss. Helen Loraine
# 3          1         0               Allison  Mr. Hudson Joshua Creighton
# 4          1         0    Allison  Mrs. Hudson J C (Bessie Waldo Daniels)
# 5          1         1                                Anderson  Mr. Harry
# 6          1         1                  Andrews  Miss. Kornelia Theodosia
# 7          1         0                             Andrews  Mr. Thomas Jr
# 8          1         1      Appleton  Mrs. Edward Dale (Charlotte Lamson)
# 9          1         0                            Artagaveytia  Mr. Ramon
# 10         1         0                             Astor  Col. John Jacob
# 11         1         1  Astor  Mrs. John Jacob (Madeleine Talmadge Force)
# ...

# %%
######################################  Groupby, Agg ###########################################

# %%
Train.groupby(['sex'])['survived'].mean() # returns series
# Out:
# sex
# female    0.727468
# male      0.190985
# Name: survived, dtype: float64

# %%
Train.groupby(['sex'])[['survived']].mean() #returns dataframe with double brackets
# Out:
#         survived
# sex
# female  0.727468
# male    0.190985

# %%
Train1 = Train.groupby(['sex'])[['survived']].mean()
Train1
# Out:
#         survived
# sex
# female  0.727468
# male    0.190985

# %%
Train1.reset_index() #old index will become a new column
# Out:
#       sex  survived
# 0  female  0.727468
# 1    male  0.190985

# %%
Train1.reset_index(drop=True)
# Out:
#    survived
# 0  0.727468
# 1  0.190985

# %%
Train1
# Out:
#         survived
# sex
# female  0.727468
# male    0.190985

# %%
Train1.reset_index(drop=True, inplace=True)
Train1
# Out:
#    survived
# 0  0.727468
# 1  0.190985

# %%
Train.groupby(['survived'])[['name']].nunique() #Number of unique passengerids who survived
# Out:
#           name
# survived
# 0          808
# 1          500

# %%
Train.groupby(['survived'])[['name']].count() #count and nunique will return same value if there are no duplicates
# Out:
#           name
# survived
# 0          809
# 1          500

# %%
Train.groupby(['sex']).agg({'age':[min,max,sum],      # find the min,max and sum of the age for each group
                                     'pclass': 'count', # find the number of passenger class entries
                                     'name': 'first',   # get the first name per group
									 'name': 'nunique'})
# Out:
#            age                      name pclass
#            min   max         sum nunique  count
# sex
# female  0.1667  76.0  11130.5834     465    466
# male    0.3333  80.0  20125.0833     842    843

# %%
######################################  Handling NAs ###########################################

# %%
Train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1309 entries, 0 to 1308
# Data columns (total 14 columns):
# pclass       1309 non-null int64
# survived     1309 non-null int64
# name         1309 non-null object
# sex          1309 non-null object
# age          1046 non-null float64
# sibsp        1309 non-null int64
# parch        1309 non-null int64
# ticket       1309 non-null object
# fare         1308 non-null float64
# cabin        295 non-null object
# embarked     1307 non-null object
# boat         486 non-null object
# body         121 non-null float64
# home.dest    745 non-null object
# dtypes: float64(3), int64(4), object(7)
# memory usage: 143.2+ KB

# %%
Train1 = Train.copy()

# %%
Train1['age'].fillna(value=Train1['age'].mean(),inplace=True)
Train1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1309 entries, 0 to 1308
# Data columns (total 14 columns):
# pclass       1309 non-null int64
# survived     1309 non-null int64
# name         1309 non-null object
# sex          1309 non-null object
# age          1309 non-null float64
# sibsp        1309 non-null int64
# parch        1309 non-null int64
# ticket       1309 non-null object
# fare         1308 non-null float64
# cabin        295 non-null object
# embarked     1307 non-null object
# boat         486 non-null object
# body         121 non-null float64
# home.dest    745 non-null object
# dtypes: float64(3), int64(4), object(7)
# memory usage: 143.2+ KB

# %%
Train1 = Train.copy()
Train1['age'].fillna(value=20,inplace=True) #multiple columns may not work. do one by one or do for all columns

# %%
Train.dropna() #removes all rows where any column is NA
Train1.embarked.dropna() #removes rows where 'Embarked' column is NA
# Out:
# 0       S
# 1       S
# 2       S
# 3       S
# 4       S
# 5       S
# 6       S
# 7       S
# 8       S
# 9       C
# 10      C
# 11      C
# 12      C
# 13      S
# 14      S
# 15      S
# 16      C
# 17      C
# 18      C
# 19      C
# 20      S
# 21      S
# 22      C
# 23      C
# 24      S
# 25      C
# 26      C
# 27      C
# 28      S
# 29      S
#        ..
# 1279    S
# 1280    S
# 1281    S
# 1282    S
# 1283    S
# 1284    S
# 1285    S
# 1286    C
# 1287    S
# 1288    S
# 1289    S
# 1290    S
# 1291    S
# 1292    S
# 1293    S
# 1294    S
# 1295    S
# 1296    S
# 1297    S
# 1298    S
# 1299    C
# 1300    C
# 1301    C
# 1302    C
# 1303    C
# 1304    C
# 1305    C
# 1306    C
# 1307    C
# 1308    S
# Name: embarked, Length: 1307, dtype: object

# %%
Train[['embarked','age']].dropna() #drops rows which has na values in any of the two columns
# Out:
#      embarked      age
# 0           S  29.0000
# 1           S   0.9167
# 2           S   2.0000
# 3           S  30.0000
# 4           S  25.0000
# 5           S  48.0000
# 6           S  63.0000
# 7           S  39.0000
# 8           S  53.0000
# 9           C  71.0000
# 10          C  47.0000
# 11          C  18.0000
# 12          C  24.0000
# 13          S  26.0000
# 14          S  80.0000
# 16          C  24.0000
# 17          C  50.0000
# 18          C  32.0000
# 19          C  36.0000
# 20          S  37.0000
# 21          S  47.0000
# 22          C  26.0000
# 23          C  42.0000
# 24          S  29.0000
# 25          C  25.0000
# 26          C  25.0000
# 27          C  19.0000
# 28          S  35.0000
# 29          S  28.0000
# 30          S  45.0000
# ...       ...      ...
# 1269        S  33.0000
# 1270        S  28.0000
# 1271        S  28.0000
# 1272        S  47.0000
# 1273        S  18.0000
# 1274        S  31.0000
# 1275        S  16.0000
# 1276        S  31.0000
# ...

# %%
Train[~Train.embarked.isnull()] #have entire dataframe where removing rows where embarked is null
# Out:
#       pclass  survived                                               name  \
# 0          1         1                      Allen  Miss. Elisabeth Walton
# 1          1         1                     Allison  Master. Hudson Trevor
# 2          1         0                       Allison  Miss. Helen Loraine
# 3          1         0               Allison  Mr. Hudson Joshua Creighton
# 4          1         0    Allison  Mrs. Hudson J C (Bessie Waldo Daniels)
# 5          1         1                                Anderson  Mr. Harry
# 6          1         1                  Andrews  Miss. Kornelia Theodosia
# 7          1         0                             Andrews  Mr. Thomas Jr
# 8          1         1      Appleton  Mrs. Edward Dale (Charlotte Lamson)
# 9          1         0                            Artagaveytia  Mr. Ramon
# 10         1         0                             Astor  Col. John Jacob
# 11         1         1  Astor  Mrs. John Jacob (Madeleine Talmadge Force)
# ...

# %%
Train.dropna(axis=1,how="any") #removes columns which has NA in any row. default axis is 0 which means row
# Out:
#       pclass  survived                                               name  \
# 0          1         1                      Allen  Miss. Elisabeth Walton
# 1          1         1                     Allison  Master. Hudson Trevor
# 2          1         0                       Allison  Miss. Helen Loraine
# 3          1         0               Allison  Mr. Hudson Joshua Creighton
# 4          1         0    Allison  Mrs. Hudson J C (Bessie Waldo Daniels)
# 5          1         1                                Anderson  Mr. Harry
# 6          1         1                  Andrews  Miss. Kornelia Theodosia
# 7          1         0                             Andrews  Mr. Thomas Jr
# 8          1         1      Appleton  Mrs. Edward Dale (Charlotte Lamson)
# 9          1         0                            Artagaveytia  Mr. Ramon
# 10         1         0                             Astor  Col. John Jacob
# 11         1         1  Astor  Mrs. John Jacob (Madeleine Talmadge Force)
# ...

# %%
Train.dropna(axis=1,how="all") #removes columns which has NA in all row
# Out:
#       pclass  survived                                               name  \
# 0          1         1                      Allen  Miss. Elisabeth Walton
# 1          1         1                     Allison  Master. Hudson Trevor
# 2          1         0                       Allison  Miss. Helen Loraine
# 3          1         0               Allison  Mr. Hudson Joshua Creighton
# 4          1         0    Allison  Mrs. Hudson J C (Bessie Waldo Daniels)
# 5          1         1                                Anderson  Mr. Harry
# 6          1         1                  Andrews  Miss. Kornelia Theodosia
# 7          1         0                             Andrews  Mr. Thomas Jr
# 8          1         1      Appleton  Mrs. Edward Dale (Charlotte Lamson)
# 9          1         0                            Artagaveytia  Mr. Ramon
# 10         1         0                             Astor  Col. John Jacob
# 11         1         1  Astor  Mrs. John Jacob (Madeleine Talmadge Force)
# ...

# %%
######################################  Handling Duplicates ###########################################

# %%
Train.drop_duplicates() #if entire row is duplicate
# Out:
#       pclass  survived                                               name  \
# 0          1         1                      Allen  Miss. Elisabeth Walton
# 1          1         1                     Allison  Master. Hudson Trevor
# 2          1         0                       Allison  Miss. Helen Loraine
# 3          1         0               Allison  Mr. Hudson Joshua Creighton
# 4          1         0    Allison  Mrs. Hudson J C (Bessie Waldo Daniels)
# 5          1         1                                Anderson  Mr. Harry
# 6          1         1                  Andrews  Miss. Kornelia Theodosia
# 7          1         0                             Andrews  Mr. Thomas Jr
# 8          1         1      Appleton  Mrs. Edward Dale (Charlotte Lamson)
# 9          1         0                            Artagaveytia  Mr. Ramon
# 10         1         0                             Astor  Col. John Jacob
# 11         1         1  Astor  Mrs. John Jacob (Madeleine Talmadge Force)
# ...

# %%
Train['cabin'].drop_duplicates() #remove if more than one row has same cabin. output will have only cabin column
# Out:
# 0            B5
# 1       C22 C26
# 5           E12
# 6            D7
# 7           A36
# 8          C101
# 9           NaN
# 10      C62 C64
# 12          B35
# 14          A23
# 16      B58 B60
# 18          D15
# 19           C6
# 20          D35
# 22         C148
# 24          C97
# 26          B49
# 28          C99
# 29          C52
# 30            T
# 31          A31
# 32           C7
# 33         C103
# 34          D22
# 36          E33
# 38          A21
# 39          B10
# 41           B4
# 44          E40
# 45          B38
#          ...
# 294         C68
# 295         C70
# 298         C53
# 300         B19
# 301         D46
# 303         D37
# 306         D26
# 308         C32
# 312         C80
# 313         C82
# 318        C128
# 319     E39 E41
# 333           D
# 339          F4
# 343         D56
# 349         F33
# 469        E101
# 490         E77
# 514          F2
# 520         D38
# 568           F
# 605       F G63
# 941       F E57
# 994       F E46
# ...

# %%
Train.cabin.nunique()
# Out:
# 186

# %%
Train.drop_duplicates(subset=['cabin']) #remove if more than one row has same cabin. output will have all the column. one row for each cabin
# Out:
#       pclass  survived                                           name     sex  \
# 0          1         1                  Allen  Miss. Elisabeth Walton  female
# 1          1         1                 Allison  Master. Hudson Trevor    male
# 5          1         1                            Anderson  Mr. Harry    male
# 6          1         1              Andrews  Miss. Kornelia Theodosia  female
# 7          1         0                         Andrews  Mr. Thomas Jr    male
# 8          1         1  Appleton  Mrs. Edward Dale (Charlotte Lamson)  female
# 9          1         0                        Artagaveytia  Mr. Ramon    male
# 10         1         0                         Astor  Col. John Jacob    male
# 12         1         1                  Aubart  Mme. Leontine Pauline  female
# 14         1         1           Barkworth  Mr. Algernon Henry Wilson    male
# 16         1         0                       Baxter  Mr. Quigg Edmond    male
# ...

# %%
######################################  Column Names ###########################################

# %%
Train1.rename(columns={'sibsp':'sib_sp'},inplace=True) #changing column names
Train1.head(n=2)
# Out:
#    pclass  survived                            name     sex      age  sib_sp  \
# 0       1         1   Allen  Miss. Elisabeth Walton  female  29.0000       0
# 1       1         1  Allison  Master. Hudson Trevor    male   0.9167       1
#
#    parch  ticket      fare    cabin embarked boat  body  \
# 0      0   24160  211.3375       B5        S    2   NaN
# 1      2  113781  151.5500  C22 C26        S   11   NaN
#
#                          home.dest
# 0                     St Louis  MO
# 1  Montreal  PQ / Chesterville  ON

# %%
Train1.columns=['pclass', 'survived', 'name', 'sex', 'age', 'sibsp', 'parch', 'ticket', 'fare', 'cabin', 'embarked','boat','body','home.dest'] #assigning all column names

# %%
######################################  Sort ###########################################

# %%
Train1 = Train1.sort_values(by=['cabin', 'age'], ascending=[True, False]) ### sort 
Train1
# Train1.sort_values(by=['Survived', 'Age'], inplace=True) #default is ascending=True
# Out:
#       pclass  survived                                               name  \
# 244        1         0                                Ross  Mr. John Hugo
# 242        1         1                      Rosenbaum  Miss. Edith Louise
# 74         1         0                        Clifford  Mr. George Quincy
# 99         1         1  Duff Gordon  Lady. (Lucille Christiana Sutherl...
# 101        1         0                       Dulles  Mr. William Crothers
# 269        1         0                         Smith  Mr. Richard William
# 100        1         1         Duff Gordon  Sir. Cosmo Edmund (Mr Morgan)
# 38         1         0                            Brady  Mr. John Bertram
# 14         1         1               Barkworth  Mr. Algernon Henry Wilson
# 239        1         0               Roebling  Mr. Washington Augustus II
# 264        1         1                Simonius-Blumer  Col. Oberst Alfons
# 105        1         0                           Evans  Miss. Edith Corse
# ...

# %%
Train1['row_index'] = Train1.groupby(['cabin']).cumcount()+1; #to assign a column with index within each group
Train1
# Out:
#       pclass  survived                                               name  \
# 244        1         0                                Ross  Mr. John Hugo
# 242        1         1                      Rosenbaum  Miss. Edith Louise
# 74         1         0                        Clifford  Mr. George Quincy
# 99         1         1  Duff Gordon  Lady. (Lucille Christiana Sutherl...
# 101        1         0                       Dulles  Mr. William Crothers
# 269        1         0                         Smith  Mr. Richard William
# 100        1         1         Duff Gordon  Sir. Cosmo Edmund (Mr Morgan)
# 38         1         0                            Brady  Mr. John Bertram
# 14         1         1               Barkworth  Mr. Algernon Henry Wilson
# 239        1         0               Roebling  Mr. Washington Augustus II
# 264        1         1                Simonius-Blumer  Col. Oberst Alfons
# 105        1         0                           Evans  Miss. Edith Corse
# ...

# %%
######################################  Concat, Append ###########################################

# %%
Train1 = Train[0:300] ; Train2 = Train[300:500] ; Train3 = Train[500:]
print(Train1.shape, Train2.shape, Train3.shape)
# Out:
# ((300, 14), (200, 14), (809, 14))

# %%
Train_final = pd.concat([Train1, Train2,Train3],axis=0) #row concatenation
Train_final.shape
# Out:
# (1309, 14)

# %%
Train_final = Train1.append([Train2,Train3]) # This line and previous line return same results
Train_final.shape
# Out:
# (1309, 14)

# %%
Train1 = Train[Train.columns[:6]] ; Train2 = Train[Train.columns[6:]]
Train_final = pd.concat([Train1, Train2],axis=1) #column concatenation
#for column concatenation, row index should be same in the dataframes to be concatenated

# %%
######################################  Merge, Join ###########################################

# %%
Sex_surv = Train.groupby('sex')[['survived']].mean()
Sex_surv.reset_index(inplace=True)
Sex_surv.columns=['sex','sex_surv_rate']
Sex_surv
# Out:
#       sex  sex_surv_rate
# 0  female       0.727468
# 1    male       0.190985

# %%
merged_df1 = pd.merge(Train,Sex_surv,how='left', on ='sex')
merged_df1
# Out:
#       pclass  survived                                               name  \
# 0          1         1                      Allen  Miss. Elisabeth Walton
# 1          1         1                     Allison  Master. Hudson Trevor
# 2          1         0                       Allison  Miss. Helen Loraine
# 3          1         0               Allison  Mr. Hudson Joshua Creighton
# 4          1         0    Allison  Mrs. Hudson J C (Bessie Waldo Daniels)
# 5          1         1                                Anderson  Mr. Harry
# 6          1         1                  Andrews  Miss. Kornelia Theodosia
# 7          1         0                             Andrews  Mr. Thomas Jr
# 8          1         1      Appleton  Mrs. Edward Dale (Charlotte Lamson)
# 9          1         0                            Artagaveytia  Mr. Ramon
# 10         1         0                             Astor  Col. John Jacob
# 11         1         1  Astor  Mrs. John Jacob (Madeleine Talmadge Force)
# ...

# %%
Train[['name','survived']].join(Train_final[['pclass','sex']], how='outer') #join is similar to merge except the key you want to join on is your index instead of a column
# Out:
#                                                    name  survived  pclass  \
# 0                         Allen  Miss. Elisabeth Walton         1       1
# 1                        Allison  Master. Hudson Trevor         1       1
# 2                          Allison  Miss. Helen Loraine         0       1
# 3                  Allison  Mr. Hudson Joshua Creighton         0       1
# 4       Allison  Mrs. Hudson J C (Bessie Waldo Daniels)         0       1
# 5                                   Anderson  Mr. Harry         1       1
# 6                     Andrews  Miss. Kornelia Theodosia         1       1
# 7                                Andrews  Mr. Thomas Jr         0       1
# 8         Appleton  Mrs. Edward Dale (Charlotte Lamson)         1       1
# 9                               Artagaveytia  Mr. Ramon         0       1
# 10                               Astor  Col. John Jacob         0       1
# 11    Astor  Mrs. John Jacob (Madeleine Talmadge Force)         1       1
# ...

# %%
Train['pclass_surv_rate']=Train.groupby('pclass')['survived'].transform('mean')
Train
# Out:
#       pclass  survived                                               name  \
# 0          1         1                      Allen  Miss. Elisabeth Walton
# 1          1         1                     Allison  Master. Hudson Trevor
# 2          1         0                       Allison  Miss. Helen Loraine
# 3          1         0               Allison  Mr. Hudson Joshua Creighton
# 4          1         0    Allison  Mrs. Hudson J C (Bessie Waldo Daniels)
# 5          1         1                                Anderson  Mr. Harry
# 6          1         1                  Andrews  Miss. Kornelia Theodosia
# 7          1         0                             Andrews  Mr. Thomas Jr
# 8          1         1      Appleton  Mrs. Edward Dale (Charlotte Lamson)
# 9          1         0                            Artagaveytia  Mr. Ramon
# 10         1         0                             Astor  Col. John Jacob
# 11         1         1  Astor  Mrs. John Jacob (Madeleine Talmadge Force)
# ...
